# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.array(["EF","Correlation","LS","EF w/o","Fisherfaces"])
ys = np.array([20,16,17,18,2.42])
plt.bar(xs, ys, align='center', color = 'r')
plt.title("Recognition Algorithm vs Error Rate for Full Faces")
plt.ylabel("Error Rate")
plt.xlabel("Recognition Algorithm")
# Out:
# Text(0.5,0,'Recognition Algorithm')

# %%
x1 = pd.DataFrame({'No of Principal components':[30,45,60,120],'Error rate_removed_eig':[20,19.18,17.5,16.9]}) #better
x2 = pd.DataFrame({'No of Principal components':[30,45,60,120],'Error rate':[22,20,21,21]})

# %%
plt.figure()
x11 = x1.plot(x = 'No of Principal components',y = 'Error rate_removed_eig')
x2.plot(ax = x11,x = 'No of Principal components',y = 'Error rate')
plt.title("Variation in performance")
# Out:
# Text(0.5,1,'Variation in performance')
